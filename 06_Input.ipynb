# %%
x = input("Enter value of x:")
print(x)
# Out:
# 10

# %%
type(x)
# Out:
# str

# %%
x = int(input("Enter value of x:"))
type(x)
# Out:
# int

# %%
y = int(input("Enter a number"))
if y>80:
    print('High')
else:
    print('Low')
# Out:
# Low
