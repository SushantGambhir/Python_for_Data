# %%
print("hello"+"world")

# %%
x = "hello"+" world"
print(x)

# %%
print(10 + '10')
#This will give error because first input is int and second is string

# %%
print(10+int('10'))
# Out:
# 20

# %%
print(str(10)+"10")
# Out:
# 1010
