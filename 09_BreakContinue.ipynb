# %%
for i in range(11):
    if i==5:
        break
    print(i)

# %%
for i in range(11):
    if i==5:
        continue
    print(i)

# %%
i = 1
while i<=10:
    if i<=5:
        print(i)
    else:
        break
    i=i+1

# %%
i = 1
while i<=10:
    if i==5:
        i=i+1
        continue
    print(i)
    i = i+1
