# %%
mytup = (1,"John",1000,"nyc")
type(mytup)
# Out:
# tuple

# %%
# Tuples are immutable: Once created, cannot be changed

# %%
# Tuples items are indexed
print(mytup[2])

# However we cannot update tuples
# mytup[2] = 2 will give error
# Out:
# 1000
