# %%
mynums = [1,2,3,4,5]

# %%
type(mynums)
# Out:
# list

# %%
country = ['India','USA','UK']

# %%
print(country)
# Out:
# ['India', 'USA', 'UK']

# %%
print(mynums[0])
print(mynums[1])
# Out:
# 1
# 2

# %%
print(mynums[-1])
# Out:
# 5

# %%
print(mynums[0:2])
# Out:
# [1, 2]

# %%
print(mynums[0:3])
# Out:
# [1, 2, 3]

# %%
print(mynums[2:])
# Out:
# [3, 4, 5]

# %%
print(mynums[:3])
# Out:
# [1, 2, 3]

# %%
print(mynums[0:4:2])
# Out:
# [1, 3]

# %%
print(mynums[0::2])
# Out:
# [1, 3, 5]

# %%
print(mynums[-3:])
# Out:
# [3, 4, 5]

# %%
print(mynums[-3:-1])
# Out:
# [3, 4]
