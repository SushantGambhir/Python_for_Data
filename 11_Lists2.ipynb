# %%
l = [1,2,3,4,5]

# %%
print(len(l))

# %%
print(2 in l)
print(8 in l)

# %%
if 1 in l:
    print('1 is in the list')
else:
    print('1 is not in the list')

# %%
for i in range(len(l)):
    print(i)

# %%
l.append(6)
print(l)

# %%
l.insert(1,7)
print(l)

# %%
l1 = [1,2,3]
l2 = [4,5,6]

# %%
l1.append(l2)

# %%
print(l1)
l1 = [1,2,3]

# %%
l1.extend(l2)
print(l1)
l1 = [1,2,3]

# %%
l

# %%
l.pop()

# %%
l

# %%
l.pop(2)

# %%
l

# %%
l3 = [1,2,3,4,5,6,2,2]

# %%
l3.remove(2)
l3

# %%
l3.clear()
l3

# %%
del l3

# %%
l3
