# %%
x = 100
print(x)
# Out:
# 100

# %%
y="Hello"
print(y)
# Out:
# Hello

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# str

# %%
i = 100
j = i
print(j)

# Alternatively we can define like i = j = 100
# Out:
# 100

# %%
a = 10
b = 20

a,b = b,a
print(a)
print(b)
# Out:
# 20
# 10

# %%
a,b,c = 10,20,30
print(a,b,c)
# Out:
# 10 20 30
