# %%
l = [1,2,3,4,5]

# %%
print(len(l))
# Out:
# 5

# %%
print(2 in l)
print(8 in l)
# Out:
# True
# False

# %%
if 1 in l:
    print('1 is in the list')
else:
    print('1 is not in the list')
# Out:
# 1 is in the list

# %%
for i in range(len(l)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
