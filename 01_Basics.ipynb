# %%
print(100)
# Out:
# 100

# %%
print('Hello')
# Out:
# Hello

# %%
print(100)
print('Hello')
# Out:
# 100
# Hello

# %%
print(100, end=" ")
print('Hello')
# By default end is "\n" (next line)
# Out:
# 100 Hello
