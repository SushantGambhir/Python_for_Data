# %%
x = 'Hello World'
print(x)
# Out:
# Hello World

# %%
print(len(x))
# Out:
# 11

# %%
x[1]
# Out:
# 'e'

# %%
x[-1]
# Out:
# 'd'

# %%
x[0:6]
# Out:
# 'Hello '

# %%
'e' in x
# Out:
# True

# %%
x = '*****hello world*****'
x.strip('*')
# Out:
# 'hello world'
